# %% [markdown]
# This notebook contains the complete workflow for the Kaggle Playground Series S6E5 competition.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import RandomizedSearchCV, train_test_split, GridSearchCV
from sklearn.metrics import roc_curve
import xgboost as xgb
from sklearn.metrics import roc_curve, auc

# %%
df = pd.read_csv("./playground-series-s6e5/train.csv")
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 439140 entries, 0 to 439139
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      439140 non-null  int64
#  1   Driver                  439140 non-null  str
#  2   Compound                439140 non-null  str
#  3   Race                    439140 non-null  str
#  4   Year                    439140 non-null  int64
#  5   PitStop                 439140 non-null  int64
#  6   LapNumber               439140 non-null  int64
#  7   Stint                   439140 non-null  int64
#  8   TyreLife                439140 non-null  float64
#  9   Position                439140 non-null  int64
#  10  LapTime (s)             439140 non-null  float64
#  11  LapTime_Delta           439140 non-null  float64
#  12  Cumulative_Degradation  439140 non-null  float64
#  13  RaceProgress            439140 non-null  float64
#  14  Position_Change         439140 non-null  float64
#  15  PitNextLap              439140 non-null  float64
# dtypes: float64(7), int64(6), str(3)
# memory usage: 53.6 MB

# %%
categorical_columns = ["Compound", "Race"]

encoder = OneHotEncoder(sparse_output=False)

one_hot_encoded = encoder.fit_transform(df[categorical_columns])

one_hot_df = pd.DataFrame(one_hot_encoded, columns=encoder.get_feature_names_out(categorical_columns))

df_new = pd.concat([df.drop(categorical_columns, axis=1), one_hot_df], axis=1)

df_new.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 439140 entries, 0 to 439139
# Data columns (total 45 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              439140 non-null  int64
#  1   Driver                          439140 non-null  str
#  2   Year                            439140 non-null  int64
#  3   PitStop                         439140 non-null  int64
#  4   LapNumber                       439140 non-null  int64
#  5   Stint                           439140 non-null  int64
#  6   TyreLife                        439140 non-null  float64
#  7   Position                        439140 non-null  int64
#  8   LapTime (s)                     439140 non-null  float64
#  9   LapTime_Delta                   439140 non-null  float64
#  10  Cumulative_Degradation          439140 non-null  float64
#  11  RaceProgress                    439140 non-null  float64
#  12  Position_Change                 439140 non-null  float64
#  13  PitNextLap                      439140 non-null  float64
#  14  Compound_HARD                   439140 non-null  float64
#  15  Compound_INTERMEDIATE           439140 non-null  float64
#  16  Compound_MEDIUM                 439140 non-null  float64
#  17  Compound_SOFT                   439140 non-null  float64
#  18  Compound_WET                    439140 non-null  float64
#  19  Race_Abu Dhabi Grand Prix       439140 non-null  float64
#  20  Race_Australian Grand Prix      439140 non-null  float64
#  21  Race_Austrian Grand Prix        439140 non-null  float64
#  22  Race_Azerbaijan Grand Prix      439140 non-null  float64
#  23  Race_Bahrain Grand Prix         439140 non-null  float64
#  24  Race_Belgian Grand Prix         439140 non-null  float64
#  25  Race_British Grand Prix         439140 non-null  float64
#  26  Race_Canadian Grand Prix        439140 non-null  float64
#  27  Race_Chinese Grand Prix         439140 non-null  float64
#  28  Race_Dutch Grand Prix           439140 non-null  float64
#  29  Race_Emilia Romagna Grand Prix  439140 non-null  float64
#  30  Race_French Grand Prix          439140 non-null  float64
#  31  Race_Hungarian Grand Prix       439140 non-null  float64
#  32  Race_Italian Grand Prix         439140 non-null  float64
#  33  Race_Japanese Grand Prix        439140 non-null  float64
#  34  Race_Las Vegas Grand Prix       439140 non-null  float64
#  35  Race_Mexico City Grand Prix     439140 non-null  float64
#  36  Race_Miami Grand Prix           439140 non-null  float64
#  37  Race_Monaco Grand Prix          439140 non-null  float64
#  38  Race_Pre-Season Testing         439140 non-null  float64
#  39  Race_Qatar Grand Prix           439140 non-null  float64
#  40  Race_Saudi Arabian Grand Prix   439140 non-null  float64
#  41  Race_Singapore Grand Prix       439140 non-null  float64
#  42  Race_Spanish Grand Prix         439140 non-null  float64
#  43  Race_São Paulo Grand Prix       439140 non-null  float64
#  44  Race_United States Grand Prix   439140 non-null  float64
# dtypes: float64(38), int64(6), str(1)
# memory usage: 150.8 MB

# %%
var = [c for c in df_new.columns if c not in ["id", "PitNextLap", "Driver"]]
target_variable = "PitNextLap"


X = df_new[var]
y = df_new[target_variable]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
param_grid = {
    'max_depth': [3, 5, 7, 10],
    'learning_rate': [0.01, 0.05, 0.1, 0.2],
    'n_estimators': [100, 500, 1000],
    'subsample': [0.7, 0.8, 0.9],
    'colsample_bytree': [0.7, 0.8, 0.9],
    'device': ['cuda']
}

grid_search = GridSearchCV(
    estimator=xgb.XGBClassifier(objective='binary:logistic'),
    param_grid=param_grid,
    scoring='roc_auc',
    cv=3,
    verbose=1,
    n_jobs=1
)

grid_search.fit(X_train, y_train)

best_xgb = grid_search.best_estimator_
y_score = best_xgb.predict_proba(X_test)[:, 1]

fpr, tpr, _ = roc_curve(y_test, y_score)
roc_auc = auc(fpr, tpr)

print(f"Best parameters: {grid_search.best_params_}")
print(f"Best AUC in CV: {grid_search.best_score_:.4f}")
# Out:
# Fitting 3 folds for each of 432 candidates, totalling 1296 fits
# /home/elia/UNI/3r/2n semestre/venv/lib/python3.13/site-packages/xgboost/core.py:751: UserWarning: [12:51:38] WARNING: /__w/xgboost/xgboost/src/common/error_msg.cc:62: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# Best parameters: {'colsample_bytree': 0.7, 'device': 'cuda', 'learning_rate': 0.05, 'max_depth': 7, 'n_estimators': 1000, 'subsample': 0.9}
# Best AUC in CV: 0.9482

# %%
best_params = {**grid_search.best_params_}

final_xgb = xgb.XGBClassifier(**best_params)

final_xgb.fit(X_train, y_train)

y_score = final_xgb.predict_proba(X_test)[:, 1]

fpr, tpr, _ = roc_curve(y_test, y_score)
roc_auc = auc(fpr, tpr)

plt.plot(fpr, tpr, lw=2, label=f'XGBoost (AUC = {roc_auc:.3f})')

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.show()


print(f"Final Model AUC: {roc_auc:.4f}")
# Out:
# Final Model AUC: 0.9500

# %%
df_test_final = pd.read_csv('./playground-series-s6e5/test.csv') 

categorical_columns = ["Compound", "Race"]

one_hot_encoded_test = encoder.transform(df_test_final[categorical_columns])
one_hot_df_test = pd.DataFrame(one_hot_encoded_test, columns=encoder.get_feature_names_out(categorical_columns))

df_test_processed = pd.concat([df_test_final.drop(categorical_columns, axis=1), one_hot_df_test], axis=1)

test_features = df_test_processed[var]

kaggle_probabilities = best_xgb.predict_proba(test_features)[:, 1]

submission = pd.DataFrame({
    'id': df_test_final['id'], 
    'target': kaggle_probabilities
})
submission.to_csv('submission.csv', index=False)
print("Submission file ready!")
# Out:
# Submission file ready!
